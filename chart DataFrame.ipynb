# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(np.random.rand(50, 4), columns=['a','b','c','d'])
df
# Out:
#            a         b         c         d
# 0   0.862837  0.723604  0.571642  0.764679
# 1   0.124663  0.122812  0.066762  0.455405
# 2   0.011722  0.337531  0.038770  0.301908
# 3   0.778187  0.523003  0.478260  0.083619
# 4   0.177868  0.234998  0.172182  0.758081
# 5   0.943780  0.363454  0.719973  0.552273
# 6   0.633858  0.158846  0.133187  0.088766
# 7   0.186714  0.298887  0.526098  0.339924
# 8   0.309216  0.057293  0.320401  0.100843
# 9   0.707607  0.895982  0.124762  0.299930
# 10  0.321234  0.595894  0.088316  0.429768
# 11  0.768867  0.641772  0.722227  0.553859
# 12  0.966453  0.817270  0.819319  0.614992
# 13  0.011255  0.811150  0.744263  0.384076
# 14  0.085121  0.944661  0.508260  0.675584
# 15  0.727552  0.986693  0.849992  0.668599
# 16  0.866698  0.043900  0.098449  0.001364
# 17  0.456168  0.119613  0.341363  0.866629
# 18  0.008711  0.186442  0.309533  0.710922
# 19  0.826254  0.401425  0.824209  0.565024
# 20  0.541709  0.018745  0.580249  0.909368
# 21  0.530236  0.082703  0.578075  0.692818
# 22  0.536576  0.030370  0.881148  0.785760
# 23  0.553515  0.368634  0.300030  0.460215
# 24  0.470445  0.944480  0.831480  0.625348
# 25  0.192298  0.468839  0.239218  0.630991
# 26  0.804663  0.509608  0.213022  0.465825
# 27  0.203534  0.877854  0.196176  0.229251
# 28  0.542716  0.594260  0.516921  0.271463
# 29  0.967334  0.332511  0.856325  0.871312
# 30  0.248810  0.922710  0.447873  0.338874
# 31  0.218462  0.773490  0.766768  0.706980
# 32  0.207850  0.809140  0.367419  0.802943
# 33  0.771425  0.335598  0.848137  0.401414
# 34  0.747295  0.822793  0.445703  0.407750
# 35  0.466680  0.275420  0.101076  0.934236
# 36  0.985523  0.676573  0.437066  0.369837
# 37  0.046319  0.811655  0.305798  0.115382
# 38  0.078668  0.675188  0.978304  0.483169
# 39  0.711169  0.702935  0.897501  0.886539
# 40  0.017734  0.491653  0.837563  0.448655
# 41  0.526289  0.824336  0.317974  0.777020
# 42  0.314714  0.167422  0.891969  0.145889
# 43  0.742298  0.878247  0.323035  0.103255
# 44  0.491396  0.550535  0.201558  0.121481
# 45  0.473449  0.399363  0.161752  0.718813
# 46  0.452518  0.921497  0.182878  0.359474
# 47  0.984841  0.198759  0.068910  0.511379
# 48  0.327025  0.747038  0.233563  0.674586
# 49  0.695062  0.747256  0.830242  0.967385

# %%
df.plot.scatter(x='a', y='b', color='red', label='Group 1')
df.plot.scatter(x='c', y='d', color='blue', label='Group 2')
# Out:
# <AxesSubplot: xlabel='c', ylabel='d'>

# %%
k=df.plot.scatter(x='a', y='b', color='red', label='Group 1')
df.plot.scatter(x='c', y='d', color='blue', label='Group 2', ax=k)
# Out:
# <AxesSubplot: xlabel='c', ylabel='d'>

# %%
df.head(10).plot.bar()
# Out:
# <AxesSubplot: >

# %%
df.head(10).plot.bar(stacked=True)
# Out:
# <AxesSubplot: >

# %%
df.head(10).plot.barh(stacked=True)
# Out:
# <AxesSubplot: >

# %%
df.plot.box()
# Out:
# <AxesSubplot: >

# %%
df.plot.box(color={'boxes':'Green', 'whiskers':'red','medians':'blue', 'caps':'Gray'})
# Out:
# <AxesSubplot: >

# %%
df.plot.box(vert=False, positions=[1,4,5,6])
# Out:
# <AxesSubplot: >

# %%
df.boxplot()
# Out:
# <AxesSubplot: >

# %%
df = pd.DataFrame(3 * np.random.rand(4,2), index=['a','b','c','d'], columns=['x','y'])
df
# Out:
#           x         y
# a  0.582353  2.884721
# b  1.391130  0.544219
# c  2.283110  2.187980
# d  2.373164  1.662949

# %%
df.plot.pie(subplots=True, figsize=(15,8))
# Out:
# array([<AxesSubplot: ylabel='x'>, <AxesSubplot: ylabel='y'>], dtype=object)
